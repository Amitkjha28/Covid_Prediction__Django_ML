# %% [markdown]
# ## Note:
#
#     1 - Yes
#     2 - No
#     97 - Does Not Apply
#     98 - It is Ignored
#     99 - No Specified
#
#     Sex : 1 - Female , 2 - Male
#
#     Patient_type :  1 - Not Hospitalized , 2 - Hosptalized
#
#     intubed : 1 - Patient used Ventilator (Yes) , 2 - Patient did not used Ventilator (No)
#
#     covid_res : 1 - covid Positive (+ve) , 2  Negative (-ve) , 3 - Awaiting Process

# %%
import pandas as pd

# %%
df=pd.read_csv('covid.csv')

# %%
df.head()
# Out:
#        id  sex  patient_type  entry_date date_symptoms   date_died  intubed  \
# 0  16169f    2             1  04-05-2020    02-05-2020  9999-99-99       97
# 1  1009bf    2             1  19-03-2020    17-03-2020  9999-99-99       97
# 2  167386    1             2  06-04-2020    01-04-2020  9999-99-99        2
# 3  0b5948    2             2  17-04-2020    10-04-2020  9999-99-99        2
# 4  0d01b5    1             2  13-04-2020    13-04-2020  22-04-2020        2
#
#    pneumonia  age  pregnancy  ...  inmsupr  hypertension  other_disease  \
# 0          2   27         97  ...        2             2              2
# 1          2   24         97  ...        2             2              2
# 2          2   54          2  ...        2             2              2
# 3          1   30         97  ...        2             2              2
# 4          2   60          2  ...        2             1              2
#
#    cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'sex', 'patient_type', 'entry_date', 'date_symptoms', 'date_died',
#        'intubed', 'pneumonia', 'age', 'pregnancy', 'diabetes', 'copd',
#        'asthma', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular',
#        'obesity', 'renal_chronic', 'tobacco', 'contact_other_covid',
#        'covid_res', 'icu'],
#       dtype='object')

# %%
covid_data=df.drop(['id', 'entry_date', 'date_symptoms', 'date_died'],axis=1)

# %%
covid_data.head(2)
# Out:
#    sex  patient_type  intubed  pneumonia  age  pregnancy  diabetes  copd  \
# 0    2             1       97          2   27         97         2     2
# 1    2             1       97          2   24         97         2     2
#
#    asthma  inmsupr  hypertension  other_disease  cardiovascular  obesity  \
# 0       2        2             2              2               2        2
# 1       2        2             2              2               2        2
#
#    renal_chronic  tobacco  contact_other_covid  covid_res  icu
# 0              2        2                    2          1   97
# 1              2        2                   99          1   97

# %%
covid_data.describe()
# Out:
#                  sex   patient_type        intubed      pneumonia  \
# count  566602.000000  566602.000000  566602.000000  566602.000000
# mean        1.506726       1.215165      76.562952       1.846262
# std         0.499955       0.410937      39.058676       0.560939
# min         1.000000       1.000000       1.000000       1.000000
# 25%         1.000000       1.000000      97.000000       2.000000
# 50%         2.000000       1.000000      97.000000       2.000000
# 75%         2.000000       1.000000      97.000000       2.000000
# max         2.000000       2.000000      99.000000      99.000000
#
#                  age      pregnancy       diabetes           copd  \
# count  566602.000000  566602.000000  566602.000000  566602.000000
# mean       42.622483      50.400692       2.210633       2.280221
# std        16.659973      47.501579       5.683523       5.327832
# min         0.000000       1.000000       1.000000       1.000000
# ...

# %%
covid_data.isnull().sum()
# Out:
# sex                    0
# patient_type           0
# intubed                0
# pneumonia              0
# age                    0
# pregnancy              0
# diabetes               0
# copd                   0
# asthma                 0
# inmsupr                0
# hypertension           0
# other_disease          0
# cardiovascular         0
# obesity                0
# renal_chronic          0
# tobacco                0
# contact_other_covid    0
# covid_res              0
# icu                    0
# dtype: int64

# %%
for i in covid_data.columns:
    print("Unique value in {} :".format(i),covid_data[i].unique())
# Out:
# Unique value in sex : [2 1]
# Unique value in patient_type : [1 2]
# Unique value in intubed : [97  2  1 99]
# Unique value in pneumonia : [ 2  1 99]
# Unique value in age : [ 27  24  54  30  60  47  63  56  41  39  46  45  28  34  38  49  25  40
#   61  31  33  52  83  43  77  37  32  53  42  57  48  59  44  65  73  71
#   51  50  35  67  55  78  29  79  36  66  74  58  84  26  80   3  75  68
#   87  69  89  76  62  18  23  70  17  72   0  81  64  88  20  15  22  14
#   16  86  92  90  82   5   7  11  21  85  95  19   1   4  97  10  93   9
#    8  12  13   6  91   2  98  96  94 100 119 101  99 103 114 106 120 105
#  102 116 104 118 109 110 117 115 113 108 107 111]
# Unique value in pregnancy : [97  2  1 98]
# Unique value in diabetes : [ 2  1 98]
# Unique value in copd : [ 2  1 98]
# Unique value in asthma : [ 2  1 98]
# Unique value in inmsupr : [ 2  1 98]
# Unique value in hypertension : [ 2  1 98]
# Unique value in other_disease : [ 2  1 98]
# ...

# %%
for i in covid_data.columns:
    print(covid_data[i].value_counts())
    print("********************************")
# Out:
# 2    287112
# 1    279490
# Name: sex, dtype: int64
# ********************************
# 1    444689
# 2    121913
# Name: patient_type, dtype: int64
# ********************************
# 97    444689
# 2     111824
# 1       9965
# 99       124
# Name: intubed, dtype: int64
# ********************************
# 2     478416
# 1      88175
# 99        11
# Name: pneumonia, dtype: int64
# ********************************
# 30     14604
# 31     13911
# 36     13890
# 38     13847
# 37     13836
#        ...
# 118        1
# 117        1
# 115        1
# 116        1
# 111        1
# Name: age, Length: 120, dtype: int64
# ********************************
# 97    287112
# 2     273840
# 1       4063
# 98      1587
# Name: pregnancy, dtype: int64
# ********************************
# 2     493790
# 1      70831
# 98      1981
# Name: diabetes, dtype: int64
# ********************************
# 2     555723
# 1       9130
# 98      1749
# Name: copd, dtype: int64
# ...

# %%
mydf = covid_data.drop(['age'],axis=1)
for i in mydf.columns:
    covid_data=covid_data[covid_data[i]<98]
    covid_data[i].replace({97:3},inplace=True)
covid_data
# Out:
#         sex  patient_type  intubed  pneumonia  age  pregnancy  diabetes  copd  \
# 0         2             1        3          2   27          3         2     2
# 7         1             1        3          2   56          2         2     2
# 13        1             1        3          2   34          2         2     2
# 15        1             1        3          2   34          2         2     2
# 16        1             1        3          2   49          2         1     2
# ...     ...           ...      ...        ...  ...        ...       ...   ...
# 566596    2             1        3          2   46          3         1     2
# 566597    2             1        3          2   58          3         1     2
# 566598    1             1        3          2   48          2         2     2
# 566600    1             1        3          1   43          2         2     2
# 566601    2             1        3          1   65          3         1     2
#
# ...

# %%
covid_data=covid_data[covid_data['covid_res']!=3]
covid_data
# Out:
#         sex  patient_type  intubed  pneumonia  age  pregnancy  diabetes  copd  \
# 0         2             1        3          2   27          3         2     2
# 7         1             1        3          2   56          2         2     2
# 13        1             1        3          2   34          2         2     2
# 15        1             1        3          2   34          2         2     2
# 16        1             1        3          2   49          2         1     2
# ...     ...           ...      ...        ...  ...        ...       ...   ...
# 499686    1             1        3          2   15          2         2     2
# 499687    2             1        3          1   77          3         2     2
# 499688    2             2        1          1   63          3         2     2
# 499689    1             1        3          2   25          2         2     2
# 499690    1             1        3          2   45          2         2     2
#
# ...

# %%
for i in covid_data.columns:
    print(covid_data[i].value_counts())
    print("********************************")
# Out:
# 2    174230
# 1    168374
# Name: sex, dtype: int64
# ********************************
# 1    290925
# 2     51679
# Name: patient_type, dtype: int64
# ********************************
# 3    290925
# 2     44679
# 1      7000
# Name: intubed, dtype: int64
# ********************************
# 2    298633
# 1     43971
# Name: pneumonia, dtype: int64
# ********************************
# 30     9016
# 31     8582
# 29     8406
# 36     8381
# 34     8343
#        ...
# 117       1
# 115       1
# 116       1
# 107       1
# 111       1
# Name: age, Length: 119, dtype: int64
# ********************************
# 3    174230
# 2    165980
# 1      2394
# Name: pregnancy, dtype: int64
# ********************************
# 2    305888
# 1     36716
# Name: diabetes, dtype: int64
# ********************************
# 2    338258
# 1      4346
# Name: copd, dtype: int64
# ********************************
# 2    332242
# 1     10362
# Name: asthma, dtype: int64
# ...

# %%
covid_data.corr()
# Out:
#                           sex  patient_type   intubed  pneumonia       age  \
# sex                  1.000000      0.082315 -0.084009  -0.081514  0.025292
# patient_type         0.082315      1.000000 -0.950458  -0.726412  0.249151
# intubed             -0.084009     -0.950458  1.000000   0.722373 -0.244105
# pneumonia           -0.081514     -0.726412  0.722373   1.000000 -0.257126
# age                  0.025292      0.249151 -0.244105  -0.257126  1.000000
# pregnancy            0.986866      0.077795 -0.080163  -0.080730  0.035323
# diabetes            -0.017180     -0.235409  0.231348   0.224559 -0.316445
# copd                -0.000984     -0.104097  0.100509   0.095072 -0.151387
# asthma               0.041235      0.012478 -0.013622  -0.012428  0.023902
# inmsupr              0.010643     -0.083772  0.080017   0.061776 -0.025318
# hypertension        -0.003410     -0.191249  0.187837   0.183182 -0.375159
# ...

# %%
import seaborn as sns
import matplotlib.pylab as plt

# %%
plt.figure(figsize=(20,20))
sns.heatmap(covid_data.corr(),annot=True,cmap='winter',vmin=0,vmax=1)
plt.show()

# %%
sns.pairplot(covid_data.corr())
plt.show()

# %%
x=covid_data.drop(['covid_res'],axis=1)
y=covid_data['covid_res']

# %%
x
# Out:
#         sex  patient_type  intubed  pneumonia  age  pregnancy  diabetes  copd  \
# 0         2             1        3          2   27          3         2     2
# 7         1             1        3          2   56          2         2     2
# 13        1             1        3          2   34          2         2     2
# 15        1             1        3          2   34          2         2     2
# 16        1             1        3          2   49          2         1     2
# ...     ...           ...      ...        ...  ...        ...       ...   ...
# 499686    1             1        3          2   15          2         2     2
# 499687    2             1        3          1   77          3         2     2
# 499688    2             2        1          1   63          3         2     2
# 499689    1             1        3          2   25          2         2     2
# 499690    1             1        3          2   45          2         2     2
#
# ...

# %%
y
# Out:
# 0         1
# 7         1
# 13        1
# 15        1
# 16        1
#          ..
# 499686    2
# 499687    2
# 499688    2
# 499689    2
# 499690    2
# Name: covid_res, Length: 342604, dtype: int64

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
model = ExtraTreesClassifier()

# %%
model.fit(x,y)
# Out:
# ExtraTreesClassifier()

# %%
print(model.feature_importances_)
# Out:
# [0.01290173 0.07657161 0.04040885 0.12807526 0.48996323 0.00995763
#  0.03215895 0.01193326 0.00977056 0.01303243 0.02115072 0.01416002
#  0.01339147 0.03009323 0.01218144 0.0160666  0.02295641 0.04522661]

# %%
feat_importances = pd.Series(model.feature_importances_, index=x.columns)
feat_importances.nlargest(18).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
print(" Shape of X_train is:{}\n Shape of Y_train is:{}\n Shape of X_test is:{}\n Shape of Y_test is:{}\n".format(x_train.shape,y_train.shape,x_test.shape,y_test.shape))
# Out:
#  Shape of X_train is:(239822, 18)
#  Shape of Y_train is:(239822,)
#  Shape of X_test is:(102782, 18)
#  Shape of Y_test is:(102782,)

# %%
# RandomForestClassifier

# %%
from sklearn import metrics

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_classifier=RandomForestClassifier()

# %%
rf_classifier.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pre_rfc=rf_classifier.predict(x_test)

# %%
rfc_score = metrics.accuracy_score(y_test, pre_rfc)

# %%
print(rfc_score)
# Out:
# 0.6371251775602732

# %%
rfc_prob=rf_classifier.predict_proba(x_test)[[0]][0]
rfc_prob
# Out:
# array([0.40332314, 0.59667686])

# %%
#DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTree = DecisionTreeClassifier(max_depth =10)

# %%
DTree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
predTree = DTree.predict(x_test)

# %%
decisionTree_score=metrics.accuracy_score(y_test, predTree)
decisionTree_score
# Out:
# 0.6488490202564652

# %%
decisionTree_prob=DTree.predict_proba(x_test)[[0]][0]
decisionTree_prob
# Out:
# array([0.38303342, 0.61696658])

# %%
import pickle
import joblib

# %%
# DecisionTreeClassifier Save model

# %%
file = open('../save_model/DTree_model.pkl', 'wb')
pickle.dump(DTree, file)

# %%
joblib.dump(DTree,'../save_model/DTree_model.jbl')
# Out:
# ['../save_model/DTree_model.jbl']

# %%
# RandomForestClassifier Save model

# %%
pickle.dump(rf_classifier,open('../save_model/rfc_model.pkl', 'wb'))

# %%
joblib.dump(rf_classifier,'../save_model/rfc_model.jbl')
# Out:
# ['../save_model/rfc_model.jbl']
